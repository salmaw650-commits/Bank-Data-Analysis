# %%
import sys
print(sys.executable)
# Out:
# c:\New project1\venv\Scripts\python.exe

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\New project1\data\banking_transactions.csv")
print(df)
# Out:
#       transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 0            1000001            17829.01               4               12.0
# 1            1000002            16401.83               1               34.3
# 2            1000003             9678.29               8               67.8
# 3            1000004            19013.38               5               17.8
# 4            1000005            13834.95               3               88.9
# ...              ...                 ...             ...                ...
# 9995         1009996             3552.90               1               36.6
# 9996         1009997            21559.69              11               14.4
# 9997         1009998             4181.33               1               84.0
# 9998         1009999            21443.71               3               33.8
# 9999         1010000            24974.25              12                0.0
#
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\New project1\data\banking_transactions.csv")
print(df)
# Out:
#       transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 0            1000001            17829.01               4               12.0
# 1            1000002            16401.83               1               34.3
# 2            1000003             9678.29               8               67.8
# 3            1000004            19013.38               5               17.8
# 4            1000005            13834.95               3               88.9
# ...              ...                 ...             ...                ...
# 9995         1009996             3552.90               1               36.6
# 9996         1009997            21559.69              11               14.4
# 9997         1009998             4181.33               1               84.0
# 9998         1009999            21443.71               3               33.8
# 9999         1010000            24974.25              12                0.0
#
# ...

# %%
df.head(10)
# Out:
#    transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 0         1000001            17829.01               4               12.0
# 1         1000002            16401.83               1               34.3
# 2         1000003             9678.29               8               67.8
# 3         1000004            19013.38               5               17.8
# 4         1000005            13834.95               3               88.9
# 5         1000006            17501.15               9               81.5
# 6         1000007             5100.73               5               17.2
# 7         1000008            15157.16               7               46.6
# 8         1000009            22804.42               7               15.9
# 9         1000010              244.04               1               84.5
#
#    transfer_frequency  anomaly_score  account_age_days  transaction_time_hour  \
# 0                  13           0.37              2354                     22
# ...

# %%
df.tail(10)
# Out:
#       transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 9990         1009991            17982.05               2               31.9
# 9991         1009992            11658.36              11                6.4
# 9992         1009993            18594.12              11               15.0
# 9993         1009994            19504.81               3                2.6
# 9994         1009995             6296.83               5                0.0
# 9995         1009996             3552.90               1               36.6
# 9996         1009997            21559.69              11               14.4
# 9997         1009998             4181.33               1               84.0
# 9998         1009999            21443.71               3               33.8
# 9999         1010000            24974.25              12                0.0
#
#       transfer_frequency  anomaly_score  account_age_days  \
# 9990                  46           0.14              2232
# ...

# %%
df = pd.read_csv(r"C:\New project1\data\banking_transactions.csv")
print(df.shape)
# Out:
# (10000, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   transaction_id                  10000 non-null  int64
#  1   transaction_amount              10000 non-null  float64
#  2   login_attempts                  10000 non-null  int64
#  3   device_risk_score               10000 non-null  float64
#  4   transfer_frequency              10000 non-null  int64
#  5   anomaly_score                   10000 non-null  float64
#  6   account_age_days                10000 non-null  int64
#  7   transaction_time_hour           10000 non-null  int64
#  8   failed_transactions_last_30d    10000 non-null  int64
#  9   avg_monthly_balance             10000 non-null  str
#  10  daily_transaction_count         10000 non-null  int64
#  11  geo_distance_km                 10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#        transaction_id  transaction_amount  login_attempts  device_risk_score  \
# count    1.000000e+04        10000.000000    10000.000000       10000.000000
# mean     1.005000e+06        12412.754004        6.438900          50.257190
# std      2.886896e+03         7200.700863        3.453558          29.414463
# min      1.000001e+06            6.270000        1.000000           0.000000
# 25%      1.002501e+06         6174.025000        3.000000          25.100000
# 50%      1.005000e+06        12322.965000        6.000000          50.200000
# 75%      1.007500e+06        18619.650000        9.000000          75.500000
# max      1.010000e+06        24997.520000       12.000000         100.000000
#
#        transfer_frequency  anomaly_score  account_age_days  \
# count        10000.000000   10000.000000      10000.000000
# mean            39.648400       0.348916       2510.240900
# std             23.419868       0.236890       1436.335019
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_amount', 'login_attempts',
#        'device_risk_score', 'transfer_frequency', 'anomaly_score',
#        'account_age_days', 'transaction_time_hour',
#        'failed_transactions_last_30d', 'avg_monthly_balance',
#        'daily_transaction_count', 'geo_distance_km',
#        'session_duration_minutes', 'transaction_velocity_score',
#        'payment_channel', 'authentication_type', 'card_present_flag',
#        'international_transaction_flag', 'suspicious_ip_flag', 'fraud_flag'],
#       dtype='str')

# %%
df[['daily_transaction_count']].head(10)
# Out:
#    daily_transaction_count
# 0                       63
# 1                       83
# 2                        9
# 3                       78
# 4                       17
# 5                       85
# 6                       12
# 7                       63
# 8                      104
# 9                       17

# %%
payment_channel = df[df['payment_channel']=='ATM']
payment_channel.head(10)
payment_channel.describe()
# Out:
#        transaction_id  transaction_amount  login_attempts  device_risk_score  \
# count    7.770000e+02          777.000000      777.000000         777.000000
# mean     1.005032e+06        12211.105611        6.338481          48.137838
# std      2.912707e+03         7196.034596        3.452546          29.117686
# min      1.000003e+06            6.270000        1.000000           0.000000
# 25%      1.002420e+06         5989.060000        3.000000          23.300000
# 50%      1.005152e+06        12261.040000        6.000000          46.800000
# 75%      1.007580e+06        18286.310000        9.000000          73.500000
# max      1.009972e+06        24925.410000       12.000000         100.000000
#
#        transfer_frequency  anomaly_score  account_age_days  \
# count          777.000000     777.000000        777.000000
# mean            38.628057       0.348546       2502.700129
# std             23.514843       0.237927       1434.620156
# ...

# %%
df[['avg_monthly_balance']].head(10)
# Out:
#   avg_monthly_balance
# 0           112760.07
# 1           118899.52
# 2           408168.98
# 3            80771.69
# 4           382265.32
# 5           204382.64
# 6           460267.17
# 7            35075.91
# 8            62872.76
# 9           384661.12

# %%
account_state = df[(df['account_age_days']>1670) & (df['daily_transaction_count']>30.000)]
account_state.shape
# Out:
# (5053, 20)

# %%
df['payment_channel'].value_counts()
# Out:
# payment_channel
# Mobile App      4804
# Web Banking     3247
# POS Terminal    1172
# ATM              777
# Name: count, dtype: int64

# %%
df['authentication_type'].value_counts()
# Out:
# authentication_type
# OTP                          4214
# Two-Factor Authentication    2384
# Password Only                1817
# Biometric                    1585
# Name: count, dtype: int64

# %%
df['geo_distance_km'].value_counts()
# Out:
# geo_distance_km
# 10163    6
# 14623    6
# 9857     5
# 11112    5
# 6303     5
#         ..
# 13905    1
# 12584    1
# 13089    1
# 14829    1
# 10795    1
# Name: count, Length: 7323, dtype: int64

# %%
df['avg_monthly_balance'].value_counts()
# Out:
# avg_monthly_balance
# 80834.5      2
# 320053.83    2
# 135032.38    2
# 112760.07    1
# 118899.52    1
#             ..
# 17919.66     1
# 8477.85      1
# 272564.27    1
# 142791.28    1
# 367234.24    1
# Name: count, Length: 9997, dtype: int64

# %%
df['failed_transactions_last_30d'].value_counts()
# Out:
# failed_transactions_last_30d
# 15    427
# 1     424
# 0     405
# 23    404
# 12    399
# 18    395
# 22    395
# 4     395
# 6     394
# 10    392
# 17    384
# 3     383
# 16    383
# 5     382
# 13    381
# 20    381
# 21    379
# 2     378
# 19    377
# 7     372
# 8     371
# 14    370
# 24    368
# 25    365
# 9     363
# 11    333
# Name: count, dtype: int64

# %%
df['daily_transaction_count'].value_counts()
# Out:
# daily_transaction_count
# 102    106
# 96     101
# 23     101
# 66      99
# 46      99
#       ...
# 5       69
# 73      67
# 82      66
# 105     62
# 112     61
# Name: count, Length: 120, dtype: int64

# %%
df['payment_channel'].unique()
# Out:
# <StringArray>
# ['POS Terminal', 'Web Banking', 'ATM', 'Mobile App']
# Length: 4, dtype: str

# %%
df['payment_channel'].nunique()
# Out:
# 4

# %%
card_data = df[df['payment_channel'].isin(['ATM'])]
card_data.head()
# Out:
#     transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 2          1000003             9678.29               8               67.8
# 31         1000032            19875.19               1               80.8
# 61         1000062            15552.41              12               93.2
# 68         1000069            19772.91              12                2.6
# 69         1000070             6139.17               6                0.0
#
#     transfer_frequency  anomaly_score  account_age_days  \
# 2                   39           0.15              1390
# 31                  60           0.07                75
# 61                  77           0.14              2563
# 68                  31           0.80              2163
# 69                   0           0.46              2723
#
#     transaction_time_hour  failed_transactions_last_30d avg_monthly_balance  \
# 2                       3                             2           408168.98
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   transaction_id                  10000 non-null  int64
#  1   transaction_amount              10000 non-null  float64
#  2   login_attempts                  10000 non-null  int64
#  3   device_risk_score               10000 non-null  float64
#  4   transfer_frequency              10000 non-null  int64
#  5   anomaly_score                   10000 non-null  float64
#  6   account_age_days                10000 non-null  int64
#  7   transaction_time_hour           10000 non-null  int64
#  8   failed_transactions_last_30d    10000 non-null  int64
#  9   avg_monthly_balance             10000 non-null  str
#  10  daily_transaction_count         10000 non-null  int64
#  11  geo_distance_km                 10000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id                    0
# transaction_amount                0
# login_attempts                    0
# device_risk_score                 0
# transfer_frequency                0
# anomaly_score                     0
# account_age_days                  0
# transaction_time_hour             0
# failed_transactions_last_30d      0
# avg_monthly_balance               0
# daily_transaction_count           0
# geo_distance_km                   0
# session_duration_minutes          0
# transaction_velocity_score        0
# payment_channel                   0
# authentication_type               0
# card_present_flag                 0
# international_transaction_flag    0
# suspicious_ip_flag                0
# fraud_flag                        0
# dtype: int64

# %%
duble=df.duplicated().sum()
if duble>0:
    display(df[df.duplicated()])
print(f"Number of duplicate rows: {duble}")
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()
print(f"Number of duplicate rows after dropping: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows after dropping: 0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['avg_monthly_balance'].describe()
# Out:
# count       10000
# unique       9997
# top       80834.5
# freq            2
# Name: avg_monthly_balance, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
x =df['transfer_frequency']
y = df['transaction_time_hour']
plt.scatter(x,y)
plt.xlabel("x_axis ")
plt.ylabel("y_label")
plt.title("corr betwwen x and y  ")
plt.show()

# %%
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
# Out:
# <Axes: >

# %%
# %who
# Out:
# account_state	 card_data	 df	 duble	 np	 payment_channel	 pd	 plt	 sns
# sys	 x	 y

# %%
df.head()
# Out:
#    transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 0         1000001            17829.01               4               12.0
# 1         1000002            16401.83               1               34.3
# 2         1000003             9678.29               8               67.8
# 3         1000004            19013.38               5               17.8
# 4         1000005            13834.95               3               88.9
#
#    transfer_frequency  anomaly_score  account_age_days  transaction_time_hour  \
# 0                  13           0.37              2354                     22
# 1                  17           0.26              3181                     17
# 2                  39           0.15              1390                      3
# 3                  42           0.55              3716                     16
# 4                  63           0.24              4694                     16
#
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_amount', 'login_attempts',
#        'device_risk_score', 'transfer_frequency', 'anomaly_score',
#        'account_age_days', 'transaction_time_hour',
#        'failed_transactions_last_30d', 'avg_monthly_balance',
#        'daily_transaction_count', 'geo_distance_km',
#        'session_duration_minutes', 'transaction_velocity_score',
#        'payment_channel', 'authentication_type', 'card_present_flag',
#        'international_transaction_flag', 'suspicious_ip_flag', 'fraud_flag'],
#       dtype='str')

# %%
df = df.drop(['transaction_velocity_score', 'anomaly_score', 'device_risk_score','transfer_frequency'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df = df.drop(['transaction_velocity_score', 'anomaly_score', 'device_risk_score','transfer_frequency'], axis=1)
#
# File c:\New project1\venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\New project1\venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   transaction_id                  10000 non-null  int64
#  1   transaction_amount              10000 non-null  float64
#  2   login_attempts                  10000 non-null  int64
#  3   account_age_days                10000 non-null  int64
#  4   transaction_time_hour           10000 non-null  int64
#  5   failed_transactions_last_30d    10000 non-null  int64
#  6   avg_monthly_balance             10000 non-null  str
#  7   daily_transaction_count         10000 non-null  int64
#  8   geo_distance_km                 10000 non-null  int64
#  9   session_duration_minutes        10000 non-null  int64
#  10  payment_channel                 10000 non-null  str
#  11  authentication_type             10000 non-null  str
# ...

# %%
df.nunique().sort_values()
# Out:
# card_present_flag                     2
# international_transaction_flag        2
# suspicious_ip_flag                    2
# fraud_flag                            2
# authentication_type                   4
# payment_channel                       4
# login_attempts                       12
# transaction_time_hour                24
# failed_transactions_last_30d         26
# daily_transaction_count             120
# session_duration_minutes            120
# account_age_days                   4339
# geo_distance_km                    7323
# transaction_amount                 9981
# avg_monthly_balance                9997
# transaction_id                    10000
# dtype: int64

# %%
df.shape
# Out:
# (10000, 16)

# %%
df['avg_monthly_balance'] = pd.to_numeric(
    df['avg_monthly_balance'],
    errors='coerce'
)

# %%
sns.histplot(df['transaction_amount'])
plt.show()

sns.boxplot(x=df['transaction_amount'])
plt.show()

# %%
sns.histplot(df['avg_monthly_balance'])
plt.show()

sns.boxplot(x=df['avg_monthly_balance'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
df[numeric_cols].hist(figsize=(15,10), bins=20)
plt.suptitle("Distributions of Numerical Features")
plt.show()
plt.figure(figsize=(15,6))
sns.boxplot(data=df[numeric_cols])
plt.xticks(rotation=90)
plt.title("Boxplot for Numerical Features")
plt.show()

# %%
cat_cols = df.select_dtypes(include=['object','bool']).columns

for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7284\2187350330.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object','bool']).columns
